# %% [markdown]
# ## Simulación de Procesos Financieros

# %% [markdown]
# - De este curso esperamos poder simular,modelar y representar distintos fenómenos financieros para lograr analizar diferentes escenarios y situaciones

# %% [markdown]
# - Asi mismo esperamos poder usar y manipular las distintas herramientas de programación implementadas en clase

# %% [markdown]
# > Las herramientas a utilizar serán las siguientes:
#     GitHub, GitKrajen, Jupyter Notebook

# %% [markdown]
# ###### Algunos ejemplos usando $LATEX$
# $$f(x) = \sin(x)$$ $$f(x) = \cos(x)$$ $$ f(x) = \frac{1}{1+x}$$

# %% [markdown]
# ### Más funciones
#
# $$\begin{equation}
# \min_{u} f_{objetivo} = \sum_{i}(y_{i}- \hat y_{i})^{2}
# \end{equation}$$
#
# $$\begin{equation}
# \frac{x^2}{x^2 + y^2} + \frac15 + \frac1{x}
# \end{equation}$$

# %% [markdown]
# ### Insertar imagenes

# %%
from IPython.display import Image

# %%
Image("/Users/Oscar González/Desktop/Documentos de Oscar/Captura.png", width=500, height=300)

# %%
E
